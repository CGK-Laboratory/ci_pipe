# %%
import caiman
import isx

# %%
from ci_pipe.pipeline import CIPipe

# %%
pipeline = CIPipe.with_videos_from_directory('input_dir', outputs_directory='output_dir', isx=isx, caiman=caiman)

# %% [markdown]
# ## Preprocesamiento de ISX

# %%
pipeline.isx.preprocess_videos()

# %% [markdown]
# ## Conversión a TIFF y corrección de movimiento con CaImAn

# %%
rpipeline.isx.export_movie_to_tiff()

# %%
pipeline.caiman.motion_correction()

# %% [markdown]
# ## Traza del pipeline

# %%
pipeline.trace()
# Out:
# Pipeline Trace of branch: Main Branch
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                            1. ISX Preprocess Videos                                             │
# │         Params: isx_pp_temporal_downsample_factor, isx_pp_spatial_downsample_factor, isx_pp_crop_rect,          │
# │                 isx_pp_crop_rect_format, isx_pp_fix_defective_pixels, isx_pp_trim_early_frames                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                          ⬇
# ...
