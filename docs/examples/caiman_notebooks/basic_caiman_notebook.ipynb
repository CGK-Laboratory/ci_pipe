# %%
# install Miniforge, which is a lightweight, open-source Conda distribution

# !mkdir -p ./conda_env

# !wget https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh -O Miniforge3.sh
# !bash Miniforge3.sh -b -p ./conda_env/miniforge3
# Out:
# --2025-11-16 18:59:50--  https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
# Resolving github.com (github.com)... 4.228.31.150
# Connecting to github.com (github.com)|4.228.31.150|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/conda-forge/miniforge/releases/download/25.9.1-0/Miniforge3-Linux-x86_64.sh [following]
# --2025-11-16 18:59:50--  https://github.com/conda-forge/miniforge/releases/download/25.9.1-0/Miniforge3-Linux-x86_64.sh
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# create new conda_env with python in it
# !source ./conda_env/miniforge3/etc/profile.d/conda.sh && conda create -n caiman-env python=3.10 -c conda-forge -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/nazarena/projects/fiuba/cgk/docs/examples/caiman_notebooks/conda_env/miniforge3/envs/caiman-env
#
#   added / updated specs:
#     - python=3.10
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-hda65f42_8
#   ca-certificates    conda-forge/noarch::ca-certificates-2025.11.12-hbd8a1cb_0
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.45-h1aa0949_0
#   libexpat           conda-forge/linux-64::libexpat-2.7.1-hecca717_0
#   libffi             conda-forge/linux-64::libffi-3.5.2-h9ec8514_0
#   libgcc             conda-forge/linux-64::libgcc-15.2.0-h767d61c_7
# ...

# %%
# install mamba on that environment
# !source ./conda_env/miniforge3/etc/profile.d/conda.sh && conda activate caiman-env && conda install mamba -c conda-forge -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/nazarena/projects/fiuba/cgk/docs/examples/caiman_notebooks/conda_env/miniforge3/envs/caiman-env
#
#   added / updated specs:
#     - mamba
#
#
# The following NEW packages will be INSTALLED:
#
#   c-ares             conda-forge/linux-64::c-ares-1.34.5-hb9d3cd8_0
#   cpp-expected       conda-forge/linux-64::cpp-expected-1.3.1-h171cf75_0
#   fmt                conda-forge/linux-64::fmt-12.0.0-h2b0788b_0
#   keyutils           conda-forge/linux-64::keyutils-1.6.3-hb9d3cd8_0
#   krb5               conda-forge/linux-64::krb5-1.21.3-h659f571_0
#   libarchive         conda-forge/linux-64::libarchive-3.8.2-gpl_h7be2006_100
#   libcurl            conda-forge/linux-64::libcurl-8.17.0-h4e3cde8_0
#   libedit            conda-forge/linux-64::libedit-3.1.20250104-pl5321h7949ede_0
#   libev              conda-forge/linux-64::libev-4.33-hd590300_2
# ...

# %%
# install caiman into that same environment
# !source ./conda_env/miniforge3/etc/profile.d/conda.sh && conda activate caiman-env && mamba install -c conda-forge caiman -y
# Out:
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# conda-forge/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s[+] 0.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━━  14.1kB /  48.8MB @  76.0kB/s  0.1s[+] 0.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━━   1.5MB /  48.8MB @   5.2MB/s  0.2s[+] 0.4s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━━━━━━   6.8MB /  48.8MB @  17.5MB/s  0.3s[+] 0.5s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━━━━  12.1MB /  48.8MB @  24.6MB/s  0.4s[+] 0.6s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━  16.9MB /  48.8MB @  28.4MB/s  0.5s[+] 0.7s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  21.9MB /  48.8MB @  31.5MB/s  0.6s[+] 0.8s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  27.1MB /  48.8MB @  34.0MB/s  0.7s[+] 0.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  30.0MB /  48.8MB @  35.3MB/s  0.8s[+] 1.0s
# ...

# %%
# make teh notebook use that env's python
import sys
sys.executable = "./conda_env/miniforge3/envs/caiman-env/bin/python"
# !which python
# Out:
# /home/nazarena/.virtualenvs/lab_sandbox/cgk/bin/python

# %%
# !source ./conda_env/miniforge3/etc/profile.d/conda.sh && conda activate caiman-env && python -c "import caiman; print('CaImAn OK')"
# Out:
# CaImAn OK

# %%
# !python -m ipykernel install --user --name=conda_env --display-name="Conda env with caiman"
# Out:
# Installed kernelspec conda_env in /home/nazarena/.local/share/jupyter/kernels/conda_env

# %%
import caiman

# %%
from caiman.source_extraction.cnmf import cnmf, params
parameter_dict = {
    'strides': (48, 48),
    'overlaps': (24, 24),
    'max_shifts': (6,6),
    'max_deviation_rigid': 3,
    'pw_rigid': True,
    'shifts_opencv': True,
    'border_nan': 'copy'
}

parameters = params.CNMFParams(params_dict=parameter_dict)
# Out:
# In setting CNMFParams, non-pathed parameters were used; this is deprecated. In some future version of Caiman, allow_legacy will default to False (and eventually will be removed)

# %%
movie_path = '/home/nazarena/projects/fiuba/cgk/docs/examples/caiman_notebooks/input_files/data_endoscope.tif'

# %%
#from caiman.motion_correction import MotionCorrect
#mc_handler = MotionCorrect(movie_path, **parameters.motion)

# %%
#mc_handler.motion_correct(save_movie=True);

# %%
#processed_files = mc_handler.mmap_file

# %%
#processed_files

# %%
#import shutil
#import os
#path_to_executed_file = processed_files[0]
#destination_directory = "/home/nazarena/projects/fiuba/cgk/docs/examples/caiman_notebooks/output_dir"
##destination_path = os.path.join(destination_directory, os.path.basename(path_to_executed_file))

#shutil.move(path_to_executed_file, destination_path)

# %%
from ci_pipe.pipeline import CIPipe

# %%
pipeline = CIPipe.with_videos_from_directory('input_files', outputs_directory='output_dir', caiman=caiman)

# %%
pipeline.caiman.motion_correction()
# Out:
# MMAP FILES:  ['/home/nazarena/caiman_data/temp/demoMovie_els__d1_60_d2_80_d3_1_order_F_frames_2000.mmap']
# MMAP FILES:  ['/home/nazarena/caiman_data/temp/data_endoscope_els__d1_128_d2_128_d3_1_order_F_frames_1000.mmap']
# NEW OUTPUTS:  [{'ids': ['5546bc0e0bf6364d763a036fc329e9ab0ccc7e1f11aff63fc6bbb6d7e46d045d'], 'value': 'output_dir/Main Branch - Step 1 - Caiman Motion Correction/demoMovie_els__d1_60_d2_80_d3_1_order_F_frames_2000-MC.tif'}, {'ids': ['5dbfbd05ed1bb136e321cff2cdd962a9fd602fa9858e3d2a87fa4836878957a5'], 'value': 'output_dir/Main Branch - Step 1 - Caiman Motion Correction/data_endoscope_els__d1_128_d2_128_d3_1_order_F_frames_1000-MC.tif'}]
